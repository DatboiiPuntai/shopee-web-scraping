# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\pantai suyasri\appdata\roaming\python\python39\site-packages (4.5.0)
# Requirement already satisfied: certifi>=2021.10.8 in d:\anaconda3\lib\site-packages (from selenium) (2021.10.8)
# Requirement already satisfied: trio~=0.17 in c:\users\pantai suyasri\appdata\roaming\python\python39\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: urllib3[socks]~=1.26 in d:\anaconda3\lib\site-packages (from selenium) (1.26.9)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\pantai suyasri\appdata\roaming\python\python39\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: sniffio in d:\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\pantai suyasri\appdata\roaming\python\python39\site-packages (from trio~=0.17->selenium) (1.0.0rc9)
# Requirement already satisfied: outcome in c:\users\pantai suyasri\appdata\roaming\python\python39\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\pantai suyasri\appdata\roaming\python\python39\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: idna in d:\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: sortedcontainers in d:\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: cffi>=1.14 in d:\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Requirement already satisfied: attrs>=19.2.0 in d:\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: pycparser in d:\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: wsproto>=0.14 in c:\users\pantai suyasri\appdata\roaming\python\python39\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in d:\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\pantai suyasri\appdata\roaming\python\python39\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
from selenium import webdriver

# %% [markdown]
# chromedriver_path = r"D:\Programming\Bootcamp#27\Class7\chromedriver.exe"

# %% [markdown]
# driver = webdriver.Chrome(executable_path=chromedriver_path)
# driver

# %%
# !pip install webdriver-manager

# %%
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# %% [markdown]
# driver = webdriver.Chrome(service=Service(chromedriver_path))

# %%
driver.get('https://shopee.co.th/')

# %%
from selenium.webdriver.common.by import By

# %%
thai_button_element = driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/div[1]/div/div[3]/div[1]/button')
thai_button_element

# %%
button_element = driver.find_element(By.CLASS_NAME, 'shopee-button-outline')
button_element

# %%
thai_button_element.click()

# %% [markdown]
# driver.find_element(By.XPATH, '/html/body/div[1]/div/div[2]/div/div/shopee-banner-popup-stateful//div/div/div/div/div/svg')

# %%
close_popup_element = driver.execute_script("return document.querySelector('shopee-banner-popup-stateful').shadowRoot.querySelector('div.shopee-popup__close-btn')")
close_popup_element

# %%
close_popup_element.click()

# %%
search_element = driver.find_element(By.XPATH, '/html/body/div[1]/div/header/div[2]/div/div[1]/div[1]/div/form/input')
search_element.send_keys('เก้าอี้ ergonomic')

# %%
from selenium.webdriver.common.keys import Keys

# %%
search_element.send_keys(Keys.ENTER)

# %%
driver.execute_script("document.body.style.zoom='10%'")

# %%
data = driver.page_source
data

# %%
import bs4
soup = bs4.BeautifulSoup(data)
soup

# %%
all_product = soup.find_all('div',{'class':"col-xs-2-4 shopee-search-item-result__item"})
all_product

# %%
product = all_product[0]
title_element = product.find('div',{'class':'ie3A+n bM+7UW Cve6sh'})
title_text = title_element.text
title_text

price_element = product.find('div',{'class':'hpDKMN'})
price_text = price_element.text
price_text

sales_element = product.find('div',{'class':'r6HknA uEPGHT'})
if sales_element is None:
    sales_text = None
else:
    sales_text = sales_element.text

product_link_element = product.find('a')
product_link = product_link_element.get('href')
product_link

# %%
data_dict = dict()
data_dict['title'] = title_text
data_dict['price'] = price_text
data_dict['sales'] = sales_text
data_dict['link'] = product_link
data_dict

# %%
data_dict_list = []
for product in all_product:
    title_element = product.find('div',{'class':'ie3A+n bM+7UW Cve6sh'})
    title_text = title_element.text

    price_element = product.find('div',{'class':'hpDKMN'})
    price_text = price_element.text

    sales_element = product.find('div',{'class':'r6HknA uEPGHT'})
    if sales_element is None:
        sales_text = None
    else:
        sales_text = sales_element.text

    product_link_element = product.find('a')
    product_link = product_link_element.get('href')
    
    data_dict = dict()
    data_dict['title'] = title_text
    data_dict['price'] = price_text
    data_dict['sales'] = sales_text
    data_dict['link'] = product_link
    data_dict_list.append(data_dict)

# %%
data_dict_list

# %%
import pandas as pd
data_df = pd.DataFrame(data_dict_list)
data_df

# %%
price_1 = '฿6,698฿4,699'
price_2 = '฿2,616 - ฿2,772'
price_3 = '฿961'

# %%
import re

# %%
price = price_2
def clean_price(price):
    result = re.findall(r'[0-9.,]+',price)
    if '-' in price:
        original_price = None
        min_price = result[0]
        max_price = result[1]
    elif len(result) == 2:
        original_price = result[0]
        min_price = result[1]
        max_price = result[1]
    elif len(result) == 1:
        original_price = result[0]
        min_price = result[0]
        max_price = result[0]
        
    price_list =  [original_price,min_price,max_price]
    price_clean_list = []
    for price in price_list:
        if price is None:
            price_clean_list.append(None)
        else:
            price_clean_list.append(int(price.replace(',','')))
    
    return price_clean_list

# %%
price_clean_ser = data_df['price'].apply(clean_price)
price_clean_df = pd.DataFrame(price_clean_ser)
price_clean_df

# %%
price_clean_list = list(price_clean_ser)
price_clean_df = pd.DataFrame(price_clean_list, columns=['Original Price', 'Min Price', 'Max Price'])
price_clean_df

# %%
price_data_df = pd.concat([data_df,price_clean_df],axis=1)
price_data_df

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time 
import pandas as pd
import bs4
import re

# %%
def get_data():
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
    driver.get('https://shopee.co.th/')
    
    thai_button = '/html/body/div[2]/div[1]/div[1]/div/div[3]/div[1]/button'
    thai_button_element = driver.find_element(By.XPATH, thai_button)
    thai_button_element.click() 
    close_popup_element = driver.execute_script("return document.querySelector('shopee-banner-popup-stateful').shadowRoot.querySelector('div.shopee-popup__close-btn')")
    close_popup_element.click() 
    # Click to get rid of popups
    
    search_element = driver.find_element(By.XPATH, '/html/body/div[1]/div/header/div[2]/div/div[1]/div[1]/div/form/input')
    search_element.send_keys('เก้าอี้ ergonomic')
    search_element.send_keys(Keys.ENTER)
    
    driver.execute_script("document.body.style.zoom='10%'")
    time.sleep(5)
    data = driver.page_source
    # Wait 5 second for whole page to load before getting page source
    
    return data

def parse_data(data):
    soup = bs4.BeautifulSoup(data)
    all_product = soup.find_all('div',{'class':'col-xs-2-4 shopee-search-item-result__item'}) 
    data_dict_list = []
    for product in all_product:
        title_element = product.find('div',{'class':'ie3A+n bM+7UW Cve6sh'})
        title_text = title_element.text

        price_element = product.find('div',{'class':'hpDKMN'})
        price_text = price_element.text

        sales_element = product.find('div',{'class':'r6HknA uEPGHT'})
        if sales_element is None:
            sales_text = None
        else:
            sales_text = sales_element.text
               
        product_link_element = product.find('a')
        product_link = product_link_element.get('href')
        
        data_dict = dict()
        data_dict['title'] = title_text
        data_dict['price'] = price_text
        data_dict['sales'] = sales_text
        data_dict['link'] = product_link
        data_dict_list.append(data_dict)
    return data_dict_list

def clean_price(price):
    result = re.findall(r'[0-9.,]+',price)
    if '-' in price:
        original_price = None
        min_price = result[0]
        max_price = result[1]
    elif len(result) == 2:
        original_price = result[0]
        min_price = result[1]
        max_price = result[1]
    elif len(result) == 1:
        original_price = result[0]
        min_price = result[0]
        max_price = result[0]
        
    price_list =  [original_price,min_price,max_price]
    price_clean_list = []
    for price in price_list:
        if price is None:
            price_clean_list.append(None)
        else:
            price_clean_list.append(int(price.replace(',','')))
    
    return price_clean_list

def clean_data(data_dict_list):
    data_df = pd.DataFrame(data_dict_list)
    price_clean_ser = data_df['price'].apply(clean_price)
    price_clean_list = list(price_clean_ser)
    price_clean_df = pd.DataFrame(price_clean_list, columns=['Original Price', 'Min Price', 'Max Price'])
    price_data_df = pd.concat([data_df,price_clean_df],axis=1)
    price_data_df = price_data_df.drop(columns=['price'])
    
    return price_data_df

# %%
data = get_data()
data_dict_list = parse_data(data)
df = clean_data(data_dict_list)
df
# Out:
# [WDM] - Downloading: 100%|████████████████████████████████████████████████████████| 6.29M/6.29M [00:03<00:00, 1.67MB/s]
#                                                 title                sales  \
# 0      เซตคู่เพื่อสุขภาพ FULI X8 ErgoChair Pro Series     ขายแล้ว 466 ชิ้น
# 1   Bewell Ergonomic chair เก้าอี้ทำงานเพื่อสุขภาพ...     ขายแล้ว 664 ชิ้น
# 2   Ergonomic chair เก้าอี้ เก้าอี้สำนักงาน เก้าอี...       ขายแล้ว 3 ชิ้น
# 3   [พร้อมส่ง][ขายดีที่สุด][รับประกัน5ปี] เก้าอี้ส...     ขายแล้ว 170 ชิ้น
# 4   Woodpanda เก้าอี้ออฟฟิศ เก้าอี้สำนักงาน เก้าอี...  ขายแล้ว 1.2พัน ชิ้น
# 5   [ผ้าเทคนิคใหม่] KUCA 2022 เก้าอี้เล่นเกมระดับไ...     ขายแล้ว 223 ชิ้น
# 6   Ergonomic chair เก้าอี้ เก้าอี้สำนักงาน เก้าอี...       ขายแล้ว 3 ชิ้น
# 7   Woodpanda เก้าอี้ออฟฟิศ เก้าอี้สำนักงาน เก้าอี...  ขายแล้ว 1.2พัน ชิ้น
# 8   Gmax เก้าอี้เกมมิ่ง Gaming Chair นั่งสบาย เก้า...       ขายแล้ว 1 ชิ้น
# 9   [ยอดขายอันดับ 1 บน Shopee] Modena เก้าอี้สุขภา...  ขายแล้ว 6.8พัน ชิ้น
# 10  เก้าอี้เพื่อสุขภาพ รุ่น BIONIC  เก้าอี้ เก้าอี...     ขายแล้ว 148 ชิ้น
# 11  XUTI ergonomics chair รุ่น EVO เก้าอี้สุขภาพ เ...      ขายแล้ว 31 ชิ้น
# 12  Xiaomi Yuemi YM Ergonomic Office Chair เก้าอี้...      ขายแล้ว 83 ชิ้น
# 13  เก้าอี้ทำงาน Ergonomic chair เบาะหนัง เบาะฟองน...       ขายแล้ว 8 ชิ้น
# 14  เก้าอี้สำนักงานเพื่อสุขภาพ FULI M8 Ergomesh Of...       ขายแล้ว 5 ชิ้น
# 15     เซตคู่เพื่อสุขภาพ FULI X8 ErgoChair Pro Series     ขายแล้ว 466 ชิ้น
# 16  Xiaomi YM ERGONOMIC Office Chair เก้าอี้ทำงาน ...      ขายแล้ว 14 ชิ้น
# 17  เซตคู่เพื่อสุขภาพ FULI X8 ErgoChair Pro Series...     ขายแล้ว 231 ชิ้น
# 18  Deli เก้าอี้ทำงาน เก้าอี้สำนักงาน เก้าอี้ ทำงา...     ขายแล้ว 876 ชิ้น
# 19  InnHome เก้าอี้สำนักงาน เก้าอี้ทำงาน Ergonomic...    ขายแล้ว 1พัน ชิ้น
# 20  KUCA 2022 รุ่นจำกัด /ชื่อร่วม หรูหรา เก้าอี้เก...      ขายแล้ว 90 ชิ้น
# 21                    เก้าอี้สุขภาพ FULI X8 ErgoChair  ขายแล้ว 1.2พัน ชิ้น
# 22  Elife Ergonomic chair เก้าอี้สำนักงาน เก้าอี้ท...      ขายแล้ว 72 ชิ้น
# 23  Elife เก้าอี้สำนักงาน Ergonomic chair เก้าอี้ส...                 None
# 24  Xiaomi youpin YM Ergonomic Office Chair เก้าอี...     ขายแล้ว 193 ชิ้น
# 25  XUTI RISE/NANO Ergonomic chair เก้าอี้ทำงานเพื...                 None
# 26  【พร้อมส่ง】☑◐Ergonomic chair  เก้าอี้หนังสไตล์น...                 None
# 27  Elife เก้าอี้ทำงาน Ergonomic chair เก้าอี้สำนั...      ขายแล้ว 72 ชิ้น
# 28                    เก้าอี้สุขภาพ FULI X8 ErgoChair     ขายแล้ว 958 ชิ้น
# 29  Bewell เก้าอี้ทำงานเพื่อสุขภาพ รุ่น FOSTER ปรั...     ขายแล้ว 129 ชิ้น
# 30  KUCA 2022 เก้าอี้เล่นเกมระดับไฮเอนด์รูปแบบใหม่...    ขายแล้ว 1พัน ชิ้น
# 31  เก้าอี้ สำนักงาน Hbada Office Adjustable Ergon...     ขายแล้ว 222 ชิ้น
# 32  W-65 เก้าอี้สำนักงาน เก้าอี้ทำงาน Ergonomic Ch...                 None
# 33  DESKSPACE Office Chair ตามหลัก Ergonomic ไม่ปว...                 None
# 34  [🔥เก็บโค้ด ลดเพิ่ม 500.-] เก้าอี้ทำงานเพื่อสุข...     ขายแล้ว 162 ชิ้น
# 35  Xiaomi Hbada Office Chair, Ergonomic Desk Chai...                 None
# 36  [พร้อมจัดส่ง] Modena ที่พักเท้าเพื่อสุขภาพ | E...     ขายแล้ว 426 ชิ้น
# 37  Gmax เก้าอี้เกมมิ่ง Gaming Chair นั่งสบาย เก้า...       ขายแล้ว 1 ชิ้น
# 38  Sihoo​ M57 Ergonomic Chair เก้าอี้สุขภาพเบาะตา...      ขายแล้ว 84 ชิ้น
# 39  【Planet】เก้าอี้สำนักงาน เก้าอี้ออฟฟิศ เก้าอี้เ...      ขายแล้ว 40 ชิ้น
# 40  InnHome เก้าอี้สำนักงาน เก้าอี้ทำงาน Ergonomic...     ขายแล้ว 239 ชิ้น
# 41  8JFL Gmax เก้าอี้เกมมิ่ง Gaming Chair นั่งสบาย...                 None
# 42  เก้าอี้สำนักงาน เก้าอี้ เก้าอี้ทำงาน เก้าอี้คอ...       ขายแล้ว 4 ชิ้น
# 43  ที่วางเท้า ที่พักเท้า ปรับความสูงได้ Ergonomic...      ขายแล้ว 32 ชิ้น
# 44  Bewell Ergonomic chair เก้าอี้ทำงานเพื่อสุขภาพ...     ขายแล้ว 664 ชิ้น
# 45  InnHome เก้าอี้ เก้าอี้สำนักงาน เก้าอี้ทำงาน  ...     ขายแล้ว 972 ชิ้น
# 46  ZYH เก้าอี้เพื่อสุขภาพ เก้าอี้ทำงาน เก้าอี้สำน...     ขายแล้ว 213 ชิ้น
# 47  PANDO Ergonomic Chair Extreme Collection แพนโด...      ขายแล้ว 31 ชิ้น
# 48    Furradec เก้าอี้เพื่อสุขภาพ Ergonomic Haya สีดำ      ขายแล้ว 27 ชิ้น
# 49  เก้าอี้ทำงาน Ergonomic chair พนักพิง TPE ยืดหย...      ขายแล้ว 12 ชิ้น
# 50  [ รับประกัน 3 ปี ] KUCA เก้าอี้ทํางาน การออกแบ...     ขายแล้ว 442 ชิ้น
# 51  เก้าอี้สำนักงาน เก้าอี้ทำงาน Ergonomic Office ...                 None
# 52  เก้าอี้เกมมิ่ง เก้าอี้ทำงาน เก้าอี้สุขภาพ  พนั...      ขายแล้ว 96 ชิ้น
# 53  [พร้อมจัดส่ง] Modena เก้าอี้เพื่อสุขภาพ รุ่น A...      ขายแล้ว 52 ชิ้น
# 54  เก้าอี้สำนักงาน เก้าอี้ทำงาน Ergonomic Office ...                 None
# 55  Elife Ergonomic chair เก้าอี้สำนักงาน เก้าอี้ท...      ขายแล้ว 72 ชิ้น
# 56  เก้าอี้ เก้าอี้สำนักงาน เก้าอี้ทำงาน มีขาตั้งเ...                 None
# 57  เก้าอี้ เก้าอี้ทำงาน เก้าอี้สำนักงาน พนักพิงปร...      ขายแล้ว 82 ชิ้น
# 58  [🔥เก็บโค้ด ลดเพิ่ม 500.-] เก้าอี้ทำงานเพื่อสุข...     ขายแล้ว 162 ชิ้น
# 59  Bewell Ergonomic Chair รุ่น Esteem เก้าอี้ทำงา...       ขายแล้ว 6 ชิ้น
#
#                                                  link  Original Price  \
# 0   /เซตคู่เพื่อสุขภาพ-FULI-X8-ErgoChair-Pro-Serie...          6698.0
# 1   /Bewell-Ergonomic-chair-เก้าอี้ทำงานเพื่อสุขภา...         29900.0
# 2   /Ergonomic-chair-เก้าอี้-เก้าอี้สำนักงาน-เก้าอ...         29000.0
# 3   /-พร้อมส่ง-ขายดีที่สุด-รับประกัน5ปี-เก้าอี้สุข...         11419.0
# 4   /Woodpanda-เก้าอี้ออฟฟิศ-เก้าอี้สำนักงาน-เก้าอ...             NaN
# 5   /-ผ้าเทคนิคใหม่-KUCA-2022-เก้าอี้เล่นเกมระดับไ...             NaN
# 6   /Ergonomic-chair-เก้าอี้-เก้าอี้สำนักงาน-เก้าอ...         29000.0
# 7   /Woodpanda-เก้าอี้ออฟฟิศ-เก้าอี้สำนักงาน-เก้าอ...             NaN
# 8   /Gmax-เก้าอี้เกมมิ่ง-Gaming-Chair-นั่งสบาย-เก้...          2548.0
# 9   /-ยอดขายอันดับ-1-บน-Shopee-Modena-เก้าอี้สุขภา...          8990.0
# 10  /เก้าอี้เพื่อสุขภาพ-รุ่น-BIONIC-เก้าอี้-เก้าอี...          9990.0
# 11  /XUTI-ergonomics-chair-รุ่น-EVO-เก้าอี้สุขภาพ-...          7199.0
# 12  /Xiaomi-Yuemi-YM-Ergonomic-Office-Chair-เก้าอี...             NaN
# 13  /เก้าอี้ทำงาน-Ergonomic-chair-เบาะหนัง-เบาะฟอง...             NaN
# 14  /เก้าอี้สำนักงานเพื่อสุขภาพ-FULI-M8-Ergomesh-O...          5499.0
# 15  /เซตคู่เพื่อสุขภาพ-FULI-X8-ErgoChair-Pro-Serie...          6698.0
# 16  /Xiaomi-YM-ERGONOMIC-Office-Chair-เก้าอี้ทำงาน...             NaN
# 17  /เซตคู่เพื่อสุขภาพ-FULI-X8-ErgoChair-Pro-Serie...          6698.0
# 18  /Deli-เก้าอี้ทำงาน-เก้าอี้สำนักงาน-เก้าอี้-ทำง...             NaN
# 19  /InnHome-เก้าอี้สำนักงาน-เก้าอี้ทำงาน-Ergonomi...          4950.0
# 20  /KUCA-2022-รุ่นจำกัด-ชื่อร่วม-หรูหรา-เก้าอี้เก...             NaN
# 21  /เก้าอี้สุขภาพ-FULI-X8-ErgoChair-i.483357779.1...          4999.0
# 22  /Elife-Ergonomic-chair-เก้าอี้สำนักงาน-เก้าอี้...             NaN
# 23  /Elife-เก้าอี้สำนักงาน-Ergonomic-chair-เก้าอี้...         16990.0
# 24  /Xiaomi-youpin-YM-Ergonomic-Office-Chair-เก้าอ...             NaN
# 25  /XUTI-RISE-NANO-Ergonomic-chair-เก้าอี้ทำงานเพ...             NaN
# 26  /【พร้อมส่ง】☑◐Ergonomic-chair-เก้าอี้หนังสไตล์น...             NaN
# 27  /Elife-เก้าอี้ทำงาน-Ergonomic-chair-เก้าอี้สำน...             NaN
# 28  /เก้าอี้สุขภาพ-FULI-X8-ErgoChair-i.483357779.1...          4999.0
# 29  /Bewell-เก้าอี้ทำงานเพื่อสุขภาพ-รุ่น-FOSTER-ปร...         15900.0
# 30  /KUCA-2022-เก้าอี้เล่นเกมระดับไฮเอนด์รูปแบบใหม...             NaN
# 31  /เก้าอี้-สำนักงาน-Hbada-Office-Adjustable-Ergo...             NaN
# 32  /W-65-เก้าอี้สำนักงาน-เก้าอี้ทำงาน-Ergonomic-C...          2349.0
# 33  /DESKSPACE-Office-Chair-ตามหลัก-Ergonomic-ไม่ป...          5490.0
# 34  /-🔥เก็บโค้ด-ลดเพิ่ม-500.-เก้าอี้ทำงานเพื่อสุขภ...         12900.0
# 35  /Xiaomi-Hbada-Office-Chair-Ergonomic-Desk-Chai...          6898.0
# 36  /-พร้อมจัดส่ง-Modena-ที่พักเท้าเพื่อสุขภาพ-Erg...          1590.0
# 37  /Gmax-เก้าอี้เกมมิ่ง-Gaming-Chair-นั่งสบาย-เก้...          2548.0
# 38  /Sihoo​-M57-Ergonomic-Chair-เก้าอี้สุขภาพเบาะต...             NaN
# 39  /【Planet】เก้าอี้สำนักงาน-เก้าอี้ออฟฟิศ-เก้าอี้...             NaN
# 40  /InnHome-เก้าอี้สำนักงาน-เก้าอี้ทำงาน-Ergonomi...          3990.0
# 41  /8JFL-Gmax-เก้าอี้เกมมิ่ง-Gaming-Chair-นั่งสบา...             NaN
# 42  /เก้าอี้สำนักงาน-เก้าอี้-เก้าอี้ทำงาน-เก้าอี้ค...          1099.0
# 43  /ที่วางเท้า-ที่พักเท้า-ปรับความสูงได้-Ergonomi...           499.0
# 44  /Bewell-Ergonomic-chair-เก้าอี้ทำงานเพื่อสุขภา...         29900.0
# 45  /InnHome-เก้าอี้-เก้าอี้สำนักงาน-เก้าอี้ทำงาน-...          1690.0
# 46  /ZYH-เก้าอี้เพื่อสุขภาพ-เก้าอี้ทำงาน-เก้าอี้สำ...             NaN
# 47  /PANDO-Ergonomic-Chair-Extreme-Collection-แพนโ...          5590.0
# 48  /Furradec-เก้าอี้เพื่อสุขภาพ-Ergonomic-Haya-สี...         10220.0
# 49  /เก้าอี้ทำงาน-Ergonomic-chair-พนักพิง-TPE-ยืดห...         14500.0
# 50  /-รับประกัน-3-ปี-KUCA-เก้าอี้ทํางาน-การออกแบบต...             NaN
# 51  /เก้าอี้สำนักงาน-เก้าอี้ทำงาน-Ergonomic-Office...             NaN
# 52  /เก้าอี้เกมมิ่ง-เก้าอี้ทำงาน-เก้าอี้สุขภาพ-พนั...          2835.0
# 53  /-พร้อมจัดส่ง-Modena-เก้าอี้เพื่อสุขภาพ-รุ่น-A...          4990.0
# 54  /เก้าอี้สำนักงาน-เก้าอี้ทำงาน-Ergonomic-Office...             NaN
# 55  /Elife-Ergonomic-chair-เก้าอี้สำนักงาน-เก้าอี้...             NaN
# 56  /เก้าอี้-เก้าอี้สำนักงาน-เก้าอี้ทำงาน-มีขาตั้ง...             NaN
# 57  /เก้าอี้-เก้าอี้ทำงาน-เก้าอี้สำนักงาน-พนักพิงป...             NaN
# 58  /-🔥เก็บโค้ด-ลดเพิ่ม-500.-เก้าอี้ทำงานเพื่อสุขภ...         12900.0
# 59  /Bewell-Ergonomic-Chair-รุ่น-Esteem-เก้าอี้ทำง...         22900.0
#
#     Min Price  Max Price
# 0        4699       4699
# 1       19500      19500
# 2        6500       6500
# 3        7137       7137
# 4        1299       1399
# 5         939       1859
# 6        6500       6500
# 7        1299       1399
# 8        1599       1599
# 9        4990       4990
# 10       4990       4990
# 11       4390       4390
# 12       7399       8099
# 13       1790       2990
# 14       4999       4999
# 15       4699       4699
# 16       7399       8099
# 17       4699       4699
# 18        999       2499
# 19       1990       1990
# 20        460       2259
# 21       3699       3699
# 22       2190       2690
# 23       5990       5990
# 24       7399       8099
# 25      16999      17999
# 26       2650       2807
# 27       1790       3180
# 28       3699       3699
# 29       7500       7500
# 30        939       1959
# 31       3106       9729
# 32       2349       2349
# 33       3890       3890
# 34      10200      10200
# 35       4138       4138
# 36        990        990
# 37       1599       1599
# 38       8499       9499
# 39        989       1369
# 40       1590       1590
# 41       1065       1270
# 42        499        499
# 43        499        499
# 44      19500      19500
# 45        690        690
# 46       5299       5899
# 47       4990       4990
# 48       4890       4890
# 49      14500      14500
# 50        975       1049
# 51       3918       9443
# 52       2835       2835
# 53       3490       3490
# 54       2449       2550
# 55       2190       2690
# 56        399        599
# 57       1350       1550
# 58      10200      10200
# 59      12500      12500
